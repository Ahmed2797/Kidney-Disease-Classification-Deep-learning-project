# %%
data = {'Ahmed':22,'Tanvir':21}

# %%
data['Ahmed']
# Out:
# 22

# %%
data.Ahmed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data.Ahmed
#
# AttributeError: 'dict' object has no attribute 'Ahmed'

# %%
from box import ConfigBox

# %%
df = ConfigBox({'Ahmed':22,'Tanvir':21})

# %%
df.Ahmed
# Out:
# 22

# %%
type(df)
# Out:
# box.config_box.ConfigBox

# %%
type(data)
# Out:
# dict

# %%
# ensoure annotation

def multiply(a:int,b:int):
    return a*b

# %%
multiply(2,3)
# Out:
# 6

# %%
multiply(2,'4')
# Out:
# '44'

# %%
! pip install ensure==1.0.4
# Out:
# ...
#   Attempting uninstall: ensure
#     Found existing installation: ensure 1.0.2
#     Uninstalling ensure-1.0.2:
#       Successfully uninstalled ensure-1.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kidney-disease-classification 1.0 requires ensure==1.0.2, but you have ensure 1.0.4 which is incompatible.
# ...

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def multiply(a:int,b:int):
    return a*b

# %%
multiply(2,'3')
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 multiply(2,'3')
#
# File ~/miniconda3/envs/kidney/lib/python3.12/site-packages/ensure/main.py:833, in WrappedFunction.__call__(self, *args, **kwargs)
#     831     if not isinstance(value, templ):
#     832         msg = "Argument {arg} of type {valt} to {f} " "does not match annotation type {t}"
# --> 833         raise EnsureError(msg.format(arg=arg, f=self.f, t=templ, valt=type(value)))
#     835 return self.f(*args, **kwargs)
#
# EnsureError: Argument b of type <class 'str'> to <function multiply at 0x7f178454c7c0> does not match annotation type <class 'int'>

# %%
multiply(2,3)
# Out:
# 6
